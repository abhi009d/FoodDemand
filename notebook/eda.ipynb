# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../notebook/data/restaurant_food_demand.csv")

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (3240, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240 entries, 0 to 3239
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 3240 non-null   object
#  1   day_of_week          3240 non-null   object
#  2   time_of_day          3240 non-null   object
#  3   food_item            3240 non-null   object
#  4   orders               3240 non-null   int64
#  5   temperature          3240 non-null   float64
#  6   rainfall_mm          3240 non-null   float64
#  7   holiday              3240 non-null   int64
#  8   local_event          3240 non-null   int64
#  9   promotion_active     3240 non-null   int64
#  10  restaurant_location  3240 non-null   object
#  11  customer_footfall    3240 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 303.9+ KB
# None
#             orders  temperature  rainfall_mm      holiday  local_event  \
# ...

# %%
print(df.isnull().sum())
# Out:
# date                   0
# day_of_week            0
# time_of_day            0
# food_item              0
# orders                 0
# temperature            0
# rainfall_mm            0
# holiday                0
# local_event            0
# promotion_active       0
# restaurant_location    0
# customer_footfall      0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['date', 'day_of_week', 'time_of_day', 'food_item', 'orders',
#        'temperature', 'rainfall_mm', 'holiday', 'local_event',
#        'promotion_active', 'restaurant_location', 'customer_footfall'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['date', 'day_of_week', 'time_of_day', 'food_item', 'orders', 'temperature', 'rainfall_mm', 'holiday', 'local_event', 'promotion_active', 'restaurant_location', 'customer_footfall']

# %%
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['date', 'day_of_week', 'time_of_day', 'food_item', 'orders', 'temperature', 'rainfall_mm', 'holiday', 'local_event', 'promotion_active', 'restaurant_location', 'customer_footfall']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['orders'], kde=True)
plt.title("Distribution of Orders")
plt.show()

# %%
sns.histplot(df['temperature'], kde=True)
plt.title("Temperature Distribution")
plt.show()

# %%
sns.histplot(df['customer_footfall'], kde=True)
plt.title("Customer Footfall Distribution")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.countplot(x='food_item', data=df)
plt.xticks(rotation=45)
plt.title("Order Counts by Food Item")
plt.show()

# %%
sns.countplot(x='day_of_week', data=df)
plt.title("Orders by Day of the Week")
plt.show()

# %%
sns.countplot(x='promotion_active', data=df)
plt.title("Orders During Promotion")
plt.show()
